# %%
# contoh List and tuple
# contoh List
datalist = [1, 2, 3, "zoro"]
print(datalist)
[1, 2, 3, 'zoro']
datalist.append("sanja")
print(datalist)
[1, 2, 3, 'zoro', 'sanja']
print(datalist)
[1, 2, 3, 'zoro', 'sanja']
datalist,insert(3, 4)
datalist.pop(1)
2
# contoh tuple
namatuple = ("yilita", "vania","ami", "padia", "ihza", "indah" )
print(len(nametuple))
vania
print(nametuple[1])
('yilita', 'vania', 'ami', 'padia', 'ihza', 'indah')
print('')
print(nametuple[1])
vania
print(nametuple[2])

# %%
# contoh List and tuple

# %%
# contoh List

# %%
datalist = [1, 2, 3, "zoro"]

# %%
print(datalist)
# Out:
# [1, 2, 3, 'zoro']

# %%
datalist.append("sanja")

# %%
print(datalist)
# Out:
# [1, 2, 3, 'zoro', 'sanja', 'sanja']

# %%
datalist.insert(3, 4)

# %%
datalist.pop(1)
# Out:
# 2

# %%
# contoh tuple

# %%
nametuple = ("yilita", "vania", "ami", "padia", "ihza", "indah")

# %%
[print(len(nametuple))]
# Out:
# 6
# [None]

# %%
print(nametuple[1])
# Out:
# vania

# %%
print(nametuple)
# Out:
# ('yilita', 'vania', 'ami', 'padia', 'ihza', 'indah')

# %%
print('')

# %%
print(nametuple[1])
# Out:
# vania

# %%
print(nametuple[2])
# Out:
# ami

# %%
print(nametuple[0])
# Out:
# yilita

# %%
print('')

# %%
for a in nametuple:
  print(a)
# Out:
# yilita
# vania
# ami
# padia
# ihza
# indah

# %%
print('')

# %%
print("METODE TUPLE")
# Out:
# METODE TUPLE

# %%
# menghitung berapa indeks yang ada di dalam tuple

# %%
print(nametuple.count("indah"))
# Out:
# 1

# %%
# mencari tau nama yang kalian cari ada di urutan no berapa

# %%
print(nametuple.index("padia"))
# Out:
# 3

# %%
# catatan tuple

# %%
# 1. tuple ialah metode yang tidak dapat di ubah

# %%
# 2. tuple ialah sifat ordered/secara urut

# %%
# 3. tuple dapat menyimpan lebih dari 1 variabel
